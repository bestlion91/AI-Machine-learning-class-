# %% [markdown]
# # Vazifa

# %%
import pandas as pd

# %%
df=pd.read_csv('Nashville Accidents Jan 2018 - Apl 2025.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216117 entries, 0 to 216116
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             216117 non-null  int64
#  1   Date and Time               216117 non-null  object
#  2   Number of Motor Vehicles    216113 non-null  float64
#  3   Number of Injuries          216114 non-null  float64
#  4   Number of Fatalities        216114 non-null  float64
#  5   Property Damage             17640 non-null   object
#  6   Hit and Run                 216103 non-null  object
#  7   Collision Type Description  203143 non-null  object
#  8   Weather Description         194653 non-null  object
#  9   Illumination Description    202657 non-null  object
#  10  Street Address              215881 non-null  object
#  11  City                        216113 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           4
# Number of Injuries                 3
# Number of Fatalities               3
# Property Damage               198477
# Hit and Run                       14
# Collision Type Description     12974
# Weather Description            21464
# Illumination Description       13460
# Street Address                   236
# City                               4
# State                              4
# Precinct                         110
# Lat                                2
# Long                               2
# HarmfulCodes                   19245
# HarmfulDescriptions            21435
# ObjectId                           0
# Zip Code                         143
# RPA                              105
# Weather                        21464
# IlluACCIDEmination             13456
# Collision Type                 12974
# Reporting Officer                 15
# ...

# %%
df=df.dropna(subset=['Number of Motor Vehicles', 'Number of Injuries', 'Number of Fatalities', 'City', 'State', 'Lat', 'Long', 'x', 'y', 'Hit and Run', 'Reporting Officer'], axis=0)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                         138
# RPA                              101
# Weather                        21461
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df.head(50)
# Out:
#     Accident Number          Date and Time  Number of Motor Vehicles  \
# 0        2008473471  7/14/2018 11:00:00 PM                       2.0
# 1        2008787228  11/16/2018 9:33:00 AM                       1.0
# 2        2009131786  2/19/2019 10:42:00 PM                       1.0
# 4       20120135824    3/8/2021 6:05:00 PM                       2.0
# 5       20130207124   7/23/2019 3:46:00 PM                       2.0
# 6       20130311458   8/23/2023 1:00:00 PM                       2.0
# 8       20150316352    4/9/2018 2:19:00 AM                       2.0
# 9       20150550257  7/23/2019 11:40:00 PM                       2.0
# 10      20170000819    1/1/2018 2:45:00 PM                       1.0
# 11      20170007441    1/3/2018 3:01:00 PM                       2.0
# 12      20170020701    1/7/2018 1:44:00 PM                       1.0
# 13      20170035976  1/11/2018 11:59:00 PM                       2.0
# 14      20170132398    2/9/2018 7:27:00 PM                       2.0
# ...

# %%
df=df.drop('Property Damage', axis=1)

# %%
df.isnull().sum()
# Out:
# Accident Number                   0
# Date and Time                     0
# Number of Motor Vehicles          0
# Number of Injuries                0
# Number of Fatalities              0
# Hit and Run                       0
# Collision Type Description    12971
# Weather Description           21461
# Illumination Description      13456
# Street Address                  233
# City                              0
# State                             0
# Precinct                        106
# Lat                               0
# Long                              0
# HarmfulCodes                  19241
# HarmfulDescriptions           21431
# ObjectId                          0
# Zip Code                        138
# RPA                             101
# Weather                       21461
# IlluACCIDEmination            13453
# Collision Type                12971
# Reporting Officer                 0
# x                                 0
# y                                 0
# ...

# %%
df['Collision Type Description'].value_counts()
# Out:
# Collision Type Description
# Front to Rear                              66258
# ANGLE                                      54207
# NOT COLLISION W/MOTOR VEHICLE-TRANSPORT    36533
# SIDESWIPE - SAME DIRECTION                 28899
# HEAD-ON                                     5254
# SIDESWIPE - OPPOSITE DIRECTION              4471
# UNKNOWN                                     3040
# OTHER                                       2316
# Rear to Side                                1163
# REAR-TO-REAR                                 975
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Accident Number                   0
# Date and Time                     0
# Number of Motor Vehicles          0
# Number of Injuries                0
# Number of Fatalities              0
# Hit and Run                       0
# Collision Type Description    12971
# Weather Description           21461
# Illumination Description      13456
# Street Address                  233
# City                              0
# State                             0
# Precinct                        106
# Lat                               0
# Long                              0
# HarmfulCodes                  19241
# HarmfulDescriptions           21431
# ObjectId                          0
# Zip Code                        138
# RPA                             101
# Weather                       21461
# IlluACCIDEmination            13453
# Collision Type                12971
# Reporting Officer                 0
# x                                 0
# y                                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216087 entries, 0 to 216116
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             216087 non-null  int64
#  1   Date and Time               216087 non-null  object
#  2   Number of Motor Vehicles    216087 non-null  float64
#  3   Number of Injuries          216087 non-null  float64
#  4   Number of Fatalities        216087 non-null  float64
#  5   Hit and Run                 216087 non-null  object
#  6   Collision Type Description  203116 non-null  object
#  7   Weather Description         194626 non-null  object
#  8   Illumination Description    202631 non-null  object
#  9   Street Address              215854 non-null  object
#  10  City                        216087 non-null  object
#  11  State                       216087 non-null  object
#  12  Precinct                    215981 non-null  object
# ...

# %%
df['Collision Type Description'].fillna(df['Collision Type Description'].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description            21461
# Illumination Description       13456
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                         138
# RPA                              101
# Weather                        21461
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df.head(10)
# Out:
#     Accident Number          Date and Time  Number of Motor Vehicles  \
# 0        2008473471  7/14/2018 11:00:00 PM                       2.0
# 1        2008787228  11/16/2018 9:33:00 AM                       1.0
# 2        2009131786  2/19/2019 10:42:00 PM                       1.0
# 4       20120135824    3/8/2021 6:05:00 PM                       2.0
# 5       20130207124   7/23/2019 3:46:00 PM                       2.0
# 6       20130311458   8/23/2023 1:00:00 PM                       2.0
# 8       20150316352    4/9/2018 2:19:00 AM                       2.0
# 9       20150550257  7/23/2019 11:40:00 PM                       2.0
# 10      20170000819    1/1/2018 2:45:00 PM                       1.0
# 11      20170007441    1/3/2018 3:01:00 PM                       2.0
#
#     Number of Injuries  Number of Fatalities Hit and Run  \
# 0                  2.0                   0.0           N
# 1                  1.0                   0.0           N
# ...

# %%
df['Weather Description'].value_counts()
# Out:
# Weather Description
# CLEAR                     138791
# CLOUDY                     28256
# RAIN                       23245
# UNKNOWN                     2368
# SNOW                        1163
# FOG                          353
# SLEET, HAIL                  201
# OTHER (NARRATIVE)            105
# BLOWING SNOW                  80
# SEVERE CROSSWIND              30
# SMOG, SMOKE                   26
# BLOWING SAND/SOIL/DIRT         5
# NO ADVERSE CONDITIONS          3
# Name: count, dtype: int64

# %%
df['Weather Description'].fillna(df['Weather Description'].mode()[0], inplace=True)

# %%
df['Weather Description'].value_counts()
# Out:
# Weather Description
# CLEAR                     160252
# CLOUDY                     28256
# RAIN                       23245
# UNKNOWN                     2368
# SNOW                        1163
# FOG                          353
# SLEET, HAIL                  201
# OTHER (NARRATIVE)            105
# BLOWING SNOW                  80
# SEVERE CROSSWIND              30
# SMOG, SMOKE                   26
# BLOWING SAND/SOIL/DIRT         5
# NO ADVERSE CONDITIONS          3
# Name: count, dtype: int64

# %%
df['Illumination Description'].fillna(df['Illumination Description'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description            21461
# Illumination Description       13456
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                         138
# RPA                              101
# Weather                        21461
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216087 entries, 0 to 216116
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             216087 non-null  int64
#  1   Date and Time               216087 non-null  object
#  2   Number of Motor Vehicles    216087 non-null  float64
#  3   Number of Injuries          216087 non-null  float64
#  4   Number of Fatalities        216087 non-null  float64
#  5   Hit and Run                 216087 non-null  object
#  6   Collision Type Description  216087 non-null  object
#  7   Weather Description         216087 non-null  object
#  8   Illumination Description    216087 non-null  object
#  9   Street Address              215854 non-null  object
#  10  City                        216087 non-null  object
#  11  State                       216087 non-null  object
#  12  Precinct                    215981 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Accident Number                   0
# Date and Time                     0
# Number of Motor Vehicles          0
# Number of Injuries                0
# Number of Fatalities              0
# Hit and Run                       0
# Collision Type Description        0
# Weather Description               0
# Illumination Description          0
# Street Address                  233
# City                              0
# State                             0
# Precinct                        106
# Lat                               0
# Long                              0
# HarmfulCodes                  19241
# HarmfulDescriptions           21431
# ObjectId                          0
# Zip Code                        138
# RPA                             101
# Weather                           0
# IlluACCIDEmination            13453
# Collision Type                12971
# Reporting Officer                 0
# x                                 0
# y                                 0
# ...

# %%
df['HarmfulCodes'].value_counts()
# Out:
# HarmfulCodes
# 12             138890
# 14               7309
# 12;14            3528
# 8                2775
# 36               2631
#                 ...
# 12;32;72            1
# 31;38;40            1
# 12;14;55;66         1
# 21;63;64            1
# 1;12;13;33          1
# Name: count, Length: 3479, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216117 entries, 0 to 216116
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             216117 non-null  int64
#  1   Date and Time               216117 non-null  object
#  2   Number of Motor Vehicles    216113 non-null  float64
#  3   Number of Injuries          216114 non-null  float64
#  4   Number of Fatalities        216114 non-null  float64
#  5   Property Damage             17640 non-null   object
#  6   Hit and Run                 216103 non-null  object
#  7   Collision Type Description  203143 non-null  object
#  8   Weather Description         194653 non-null  object
#  9   Illumination Description    202657 non-null  object
#  10  Street Address              215881 non-null  object
#  11  City                        216113 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                         138
# RPA                              101
# Weather                        21461
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                         138
# RPA                              101
# Weather                        21461
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df['Weather'].value_counts()
# Out:
# Weather
# 21.0    138791
# 22.0     28256
# 2.0      23245
# 99.0      2368
# 4.0       1163
# 5.0        353
# 3.0        201
# 98.0       105
# 28.0        80
# 10.0        30
# 8.0         26
# 30.0         5
# 1.0          3
# Name: count, dtype: int64

# %%
df['Weather'].fillna(df['Weather'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                         138
# RPA                              101
# Weather                            0
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df['Zip Code'].value_counts()
# Out:
# Zip Code
# 37013.000000    23584
# 37211.000000    22379
# 37210.000000    17140
# 37207.000000    17059
# 37203.000000    16360
# 37115.000000    14658
# 37217.000000    11465
# 37209.000000    10322
# 37214.000000     9723
# 37206.000000     7625
# 37076.000000     7482
# 37208.000000     6822
# 37204.000000     5841
# 37221.000000     4968
# 37205.000000     4319
# 37215.000000     4059
# 37218.000000     3789
# 37212.000000     3738
# 37213.000000     3384
# 37216.000000     3273
# 37027.000000     2916
# 37201.000000     2824
# 37189.000000     2384
# 37138.000000     2087
# 37220.000000     1996
# 37219.000000     1489
# 37080.000000     1477
# 37072.000000     1234
# 37228.000000     1123
# 37135.000000      190
# 37240.000000      169
# 37172.392009      138
# 37015.000000       38
# 37122.000000       32
# Name: count, dtype: int64

# %%
df['Zip Code'].fillna(df['Zip Code'].median(), inplace=True)
# Out:
# C:\Users\aaa\AppData\Local\Temp\ipykernel_3460\488978658.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Zip Code'].fillna(df['Zip Code'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                           0
# RPA                              101
# Weather                            0
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df['RPA'].value_counts()
# Out:
# RPA
# 8865.0     2574
# 8861.0     1740
# 8651.0     1506
# 8705.0     1432
# 8927.0     1429
#            ...
# 19941.0       1
# 8001.0        1
# 1722.0        1
# 1735.0        1
# 3179.0        1
# Name: count, Length: 1970, dtype: int64

# %%
df['RPA'].fillna(df['RPA'].median(), inplace=True)
# Out:
# C:\Users\aaa\AppData\Local\Temp\ipykernel_3460\2942267161.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RPA'].fillna(df['RPA'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                   233
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                           0
# RPA                                0
# Weather                            0
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df['Street Address']
# Out:
# 0                 28TH AVE N & JEFFERSON ST
# 1            DR D B TODD JR BLVD & PEARL ST
# 2                     4953 ASHLAND CITY HWY
# 4               W TRINITY LN & E TRINITY LN
# 5                              MM 7 2 I 440
#                         ...
# 216112      DICKERSON PIKE & DICKERSON PIKE
# 216113    NOLENSVILLE RD & NOLENSVILLE PIKE
# 216114                         MM 5 6 I-440
# 216115               BROADWAY & MCGAVOCK ST
# 216116                UNKNOWN RAMP  &  ROAD
# Name: Street Address, Length: 216087, dtype: object

# %%
df['Street Address'].value_counts()
# Out:
# Street Address
# I40 E EXT RAMP & I 40                     876
# I40 W EXT RAMP & I 40                     847
# I24 W EXT RAMP & I 24                     773
# I24 E EXT RAMP & I 24                     722
# MURFREESBORO PKE & MOUNTAIN SPRINGS RD    581
#                                          ...
# 29 WHITSETT RD                              1
# 4600 ARTELIA DR                             1
# MM 96 8 I 65                                1
# CLARIDGE DR & LOCKWOOD DR                   1
# TUSCULUM CT & JOANN CT                      1
# Name: count, Length: 30303, dtype: int64

# %%
df['Street Address'].fillna('I40 E EXT RAMP & I 40', inplace=True)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                     0
# City                               0
# State                              0
# Precinct                         106
# Lat                                0
# Long                               0
# HarmfulCodes                  216087
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                           0
# RPA                                0
# Weather                            0
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# ...

# %%
df['Precinct'].value_counts()
# Out:
# Precinct
# SOUTH     50436
# HERMIT    35675
# MIDTOW    30370
# NORTH     22198
# WEST      20353
# MADISO    19324
# CENTRA    18992
# EAST      18633
# Name: count, dtype: int64

# %%
df['Precinct'].fillna('Precinct', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216087 entries, 0 to 216116
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             216087 non-null  int64
#  1   Date and Time               216087 non-null  object
#  2   Number of Motor Vehicles    216087 non-null  float64
#  3   Number of Injuries          216087 non-null  float64
#  4   Number of Fatalities        216087 non-null  float64
#  5   Hit and Run                 216087 non-null  object
#  6   Collision Type Description  216087 non-null  object
#  7   Weather Description         216087 non-null  object
#  8   Illumination Description    216087 non-null  object
#  9   Street Address              216087 non-null  object
#  10  City                        216087 non-null  object
#  11  State                       216087 non-null  object
#  12  Precinct                    216087 non-null  object
# ...

# %%
df=df.drop('HarmfulCodes', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df=df.drop('HarmfulCodes', axis=1)
#
# File c:\Users\aaa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                     0
# City                               0
# State                              0
# Precinct                           0
# Lat                                0
# Long                               0
# HarmfulDescriptions           216087
# ObjectId                           0
# Zip Code                           0
# RPA                                0
# Weather                            0
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# y                                  0
# dtype: int64

# %%
df.head(50)
# Out:
#     Accident Number          Date and Time  Number of Motor Vehicles  \
# 0        2008473471  7/14/2018 11:00:00 PM                       2.0
# 1        2008787228  11/16/2018 9:33:00 AM                       1.0
# 2        2009131786  2/19/2019 10:42:00 PM                       1.0
# 4       20120135824    3/8/2021 6:05:00 PM                       2.0
# 5       20130207124   7/23/2019 3:46:00 PM                       2.0
# 6       20130311458   8/23/2023 1:00:00 PM                       2.0
# 8       20150316352    4/9/2018 2:19:00 AM                       2.0
# 9       20150550257  7/23/2019 11:40:00 PM                       2.0
# 10      20170000819    1/1/2018 2:45:00 PM                       1.0
# 11      20170007441    1/3/2018 3:01:00 PM                       2.0
# 12      20170020701    1/7/2018 1:44:00 PM                       1.0
# 13      20170035976  1/11/2018 11:59:00 PM                       2.0
# 14      20170132398    2/9/2018 7:27:00 PM                       2.0
# ...

# %%
df=df.drop('HarmfulDescriptions', axis=1)

# %%
df.isnull().sum()
# Out:
# Accident Number                    0
# Date and Time                      0
# Number of Motor Vehicles           0
# Number of Injuries                 0
# Number of Fatalities               0
# Hit and Run                        0
# Collision Type Description         0
# Weather Description                0
# Illumination Description           0
# Street Address                     0
# City                               0
# State                              0
# Precinct                           0
# Lat                                0
# Long                               0
# ObjectId                           0
# Zip Code                           0
# RPA                                0
# Weather                            0
# IlluACCIDEmination            216087
# Collision Type                216087
# Reporting Officer                  0
# x                                  0
# y                                  0
# dtype: int64

# %%
df['IlluACCIDEmination'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         None
# 1         None
# 2         None
# 4         None
# 5         None
#           ...
# 216112    None
# 216113    None
# 216114    None
# 216115    None
# 216116    None
# Name: IlluACCIDEmination, Length: 216087, dtype: object>

# %%
df['IlluACCIDEmination'].nunique()
# Out:
# 0

# %%
df['IlluACCIDEmination'].fillna('None', inplace=True)

# %%
df['Collision Type'].fillna('Collision Type', inplace=True)
# Out:
# C:\Users\aaa\AppData\Local\Temp\ipykernel_3460\2513356382.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Collision Type'].fillna('Collision Type', inplace=True)

# %%
df.isnull().sum()
# Out:
# Accident Number               0
# Date and Time                 0
# Number of Motor Vehicles      0
# Number of Injuries            0
# Number of Fatalities          0
# Hit and Run                   0
# Collision Type Description    0
# Weather Description           0
# Illumination Description      0
# Street Address                0
# City                          0
# State                         0
# Precinct                      0
# Lat                           0
# Long                          0
# ObjectId                      0
# Zip Code                      0
# RPA                           0
# Weather                       0
# IlluACCIDEmination            0
# Collision Type                0
# Reporting Officer             0
# x                             0
# y                             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216087 entries, 0 to 216116
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident Number             216087 non-null  int64
#  1   Date and Time               216087 non-null  object
#  2   Number of Motor Vehicles    216087 non-null  float64
#  3   Number of Injuries          216087 non-null  float64
#  4   Number of Fatalities        216087 non-null  float64
#  5   Hit and Run                 216087 non-null  object
#  6   Collision Type Description  216087 non-null  object
#  7   Weather Description         216087 non-null  object
#  8   Illumination Description    216087 non-null  object
#  9   Street Address              216087 non-null  object
#  10  City                        216087 non-null  object
#  11  State                       216087 non-null  object
#  12  Precinct                    216087 non-null  object
# ...
