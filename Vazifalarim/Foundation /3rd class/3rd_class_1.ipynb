# %% [markdown]
# # 3-dars uchun 2-dataset

# %%
import pandas as pd

# %%
df=pd.read_csv('Flood_Prediction_NCR_Philippines.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7308 non-null   object
#  1   Location          7308 non-null   object
#  2   Rainfall_mm       7281 non-null   float64
#  3   WaterLevel_m      7134 non-null   float64
#  4   SoilMoisture_pct  7282 non-null   float64
#  5   Elevation_m       7308 non-null   int64
#  6   FloodOccurrence   7308 non-null   int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 399.8+ KB

# %%
df.isnull().sum()
# Out:
# Date                  0
# Location              0
# Rainfall_mm          27
# WaterLevel_m        174
# SoilMoisture_pct     26
# Elevation_m           0
# FloodOccurrence       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in df.columns:
    encoder=LabelEncoder()
    if df[col].isnull().any():
        df[col].fillna(df[col].mode()[0],inplace=True)
# Out:
# C:\Users\aaa\AppData\Local\Temp\ipykernel_9220\428104347.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7308 non-null   object
#  1   Location          7308 non-null   object
#  2   Rainfall_mm       7308 non-null   float64
#  3   WaterLevel_m      7308 non-null   float64
#  4   SoilMoisture_pct  7308 non-null   float64
#  5   Elevation_m       7308 non-null   int64
#  6   FloodOccurrence   7308 non-null   int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 399.8+ KB

# %% [markdown]
# # Encoding qilish

# %%
df.head()
# Out:
#          Date     Location  Rainfall_mm  WaterLevel_m  SoilMoisture_pct  \
# 0  01/01/2016  Quezon City         12.0           0.5              15.3
# 1  01/01/2016     Marikina         10.6           1.8              23.2
# 2  01/01/2016       Manila          5.7           0.5              15.6
# 3  01/01/2016        Pasig          3.7           0.5               5.0
# 4  02/01/2016  Quezon City          3.4           0.5              13.3
#
#    Elevation_m  FloodOccurrence
# 0           43                0
# 1           15                0
# 2            5                0
# 3            5                0
# 4           43                0

# %%
for col in df.columns:
    encoder=LabelEncoder()
    if df[col].dtype=='object':
        df[col]=encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7308 non-null   int64
#  1   Location          7308 non-null   int64
#  2   Rainfall_mm       7308 non-null   float64
#  3   WaterLevel_m      7308 non-null   float64
#  4   SoilMoisture_pct  7308 non-null   float64
#  5   Elevation_m       7308 non-null   int64
#  6   FloodOccurrence   7308 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 399.8 KB

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
minmax=MinMaxScaler()
standard=StandardScaler()
robust=RobustScaler()

# %%
num_col=df.columns.drop('FloodOccurrence')
num_robust=['Rainfall_mm','WaterLevel_m','Date']
num_standard=['SoilMoisture_pct','Elevation_m','Location']

# %%
#df[num_col]=minmax.fit_transform(df[num_col])
df[num_robust]=robust.fit_transform(df[num_robust])
df[num_standard]=standard.fit_transform(df[num_standard])

# %%
df.head(25)
# Out:
#         Date  Location  Rainfall_mm  WaterLevel_m  SoilMoisture_pct  \
# 0  -0.998906  1.341641     0.410557     -0.307692          0.025800
# 1  -0.998906 -0.447214     0.246334      0.692308          1.339976
# 2  -0.998906 -1.341641    -0.328446     -0.307692          0.075705
# 3  -0.998906  0.447214    -0.563050     -0.307692         -1.687621
# 4  -0.933260  1.341641    -0.598240     -0.307692         -0.306904
# 5  -0.933260 -0.447214    -0.914956     -0.307692         -0.739417
# 6  -0.933260 -1.341641    -0.375367     -0.307692         -0.323539
# 7  -0.933260  0.447214     0.891496     -0.307692         -0.024106
# 8  -0.867615  1.341641    -0.035191     -0.307692         -1.055485
# 9  -0.867615 -0.447214     0.304985     -0.307692          0.242056
# 10 -0.867615 -1.341641    -0.715543     -0.307692         -0.489890
# 11 -0.867615  0.447214     0.809384     -0.307692          0.325232
# 12 -0.801969  1.341641    -0.762463     -0.307692         -1.288377
# ...

# %% [markdown]
# # Model training

# %%
y=df['FloodOccurrence']

# %%
x=df.drop('FloodOccurrence',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (5846, 6)

# %%
x_test.shape
# Out:
# (1462, 6)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr
# Out:
# LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()
