# %% [markdown]
# # 3-dars uchun 3-dataset

# %%
import pandas as pd

# %%
df=pd.read_csv('football injury.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         800 non-null    int64
#  1   Height_cm                   799 non-null    float64
#  2   Weight_kg                   799 non-null    float64
#  3   Position                    799 non-null    object
#  4   Training_Hours_Per_Week     798 non-null    float64
#  5   Matches_Played_Past_Season  799 non-null    float64
#  6   Previous_Injury_Count       799 non-null    float64
#  7   Knee_Strength_Score         797 non-null    float64
#  8   Hamstring_Flexibility       519 non-null    float64
#  9   Reaction_Time_ms            745 non-null    float64
#  10  Balance_Test_Score          793 non-null    float64
#  11  Sprint_Speed_10m_s          788 non-null    float64
#  12  Agility_Score               795 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Age                             0
# Height_cm                       1
# Weight_kg                       1
# Position                        1
# Training_Hours_Per_Week         2
# Matches_Played_Past_Season      1
# Previous_Injury_Count           1
# Knee_Strength_Score             3
# Hamstring_Flexibility         281
# Reaction_Time_ms               55
# Balance_Test_Score              7
# Sprint_Speed_10m_s             12
# Agility_Score                   5
# Sleep_Hours_Per_Night          15
# Stress_Level_Score              5
# Nutrition_Quality_Score         3
# Warmup_Routine_Adherence        0
# Injury_Next_Season              0
# BMI                             0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype=='object':
        if df[col].isnull().any():
            df[col].fillna(df[col].mode()[0],inplace=True)
    else:
        df[col].fillna(df[col].mean(),inplace=True)
# Out:
# C:\Users\aaa\AppData\Local\Temp\ipykernel_16368\2474206149.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(),inplace=True)
# C:\Users\aaa\AppData\Local\Temp\ipykernel_16368\2474206149.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         800 non-null    int64
#  1   Height_cm                   800 non-null    float64
#  2   Weight_kg                   800 non-null    float64
#  3   Position                    800 non-null    object
#  4   Training_Hours_Per_Week     800 non-null    float64
#  5   Matches_Played_Past_Season  800 non-null    float64
#  6   Previous_Injury_Count       800 non-null    float64
#  7   Knee_Strength_Score         800 non-null    float64
#  8   Hamstring_Flexibility       800 non-null    float64
#  9   Reaction_Time_ms            800 non-null    float64
#  10  Balance_Test_Score          800 non-null    float64
#  11  Sprint_Speed_10m_s          800 non-null    float64
#  12  Agility_Score               800 non-null    float64
# ...

# %% [markdown]
# # Encoding

# %%
df['Position'].value_counts()
# Out:
# Position
# Midfielder    214
# Defender      203
# Forward       197
# Goalkeeper    186
# Name: count, dtype: int64

# %%
# dummies=pd.get_dummies(df['Position'],prefix='Edit', dtype=int)
# df=pd.concat([df.drop(columns=['Position']),dummies],axis=1)
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
df['Position_new']=encoder.fit_transform(df['Position'])
df.drop('Position', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         800 non-null    int64
#  1   Height_cm                   800 non-null    float64
#  2   Weight_kg                   800 non-null    float64
#  3   Training_Hours_Per_Week     800 non-null    float64
#  4   Matches_Played_Past_Season  800 non-null    float64
#  5   Previous_Injury_Count       800 non-null    float64
#  6   Knee_Strength_Score         800 non-null    float64
#  7   Hamstring_Flexibility       800 non-null    float64
#  8   Reaction_Time_ms            800 non-null    float64
#  9   Balance_Test_Score          800 non-null    float64
#  10  Sprint_Speed_10m_s          800 non-null    float64
#  11  Agility_Score               800 non-null    float64
#  12  Sleep_Hours_Per_Night       800 non-null    float64
# ...

# %%
df['Position_new']
# Out:
# 0      3
# 1      3
# 2      1
# 3      0
# 4      3
#       ..
# 795    2
# 796    0
# 797    2
# 798    2
# 799    3
# Name: Position_new, Length: 800, dtype: int64

# %% [markdown]
# # Scaling

# %%
df.head(20)
# Out:
#     Age  Height_cm  Weight_kg  Training_Hours_Per_Week  \
# 0    22      173.0       64.0                11.575308
# 1    18      170.0       67.0                12.275869
# 2    22      186.0       75.0                12.254896
# 3    20      172.0       62.0                 9.006678
# 4    18      172.0       94.0                12.683668
# 5    23      189.0       89.0                10.262987
# 6    22      189.0       71.0                 8.069288
# 7    23      184.0       75.0                 6.407939
# 8    22      174.0       71.0                10.554930
# 9    23      185.0       76.0                11.899732
# 10   18      178.0       62.0                 7.884849
# 11   19      188.0       81.0                11.132568
# 12   18      183.0       72.0                13.344094
# 13   19      198.0       75.0                10.026712
# 14   21      181.0       82.0                10.697365
# 15   18      174.0       69.0                13.422844
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
minmax=MinMaxScaler()
standard=StandardScaler()
robust=RobustScaler()

# %%
num_col=df.columns.drop('Injury_Next_Season','Warmup_Routine_Adherence')
df[num_col]=minmax.fit_transform(df[num_col])

# %%
df.head()
# Out:
#         Age  Height_cm  Weight_kg  Training_Hours_Per_Week  \
# 0  0.666667   0.413043   0.316667                 0.474183
# 1  0.000000   0.347826   0.366667                 0.524704
# 2  0.666667   0.695652   0.500000                 0.523192
# 3  0.333333   0.391304   0.283333                 0.288944
# 4  0.000000   0.391304   0.816667                 0.554113
#
#    Matches_Played_Past_Season  Previous_Injury_Count  Knee_Strength_Score  \
# 0                    0.911765                  0.125             0.603944
# 1                    0.941176                  0.250             0.487683
# 2                    0.205882                  0.250             0.594409
# 3                    0.176471                  0.125             0.732831
# 4                    0.147059                  0.250             0.587383
#
#    Hamstring_Flexibility  Reaction_Time_ms  Balance_Test_Score  \
# 0               0.506726          0.824486            0.779985
# ...

# %% [markdown]
# # Model training

# %%
y=df['Injury_Next_Season']

# %%
x=df.drop('Injury_Next_Season',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (640, 18)

# %%
x_test.shape
# Out:
# (160, 18)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr
# Out:
# LogisticRegression()

# %%
lr.fit(x_test,y_test)
# Out:
# LogisticRegression()
